# %%
import pandas as pd

# %%
df = pd.read_parquet("queries.parquet")

# %%
df
# Out:
#          model_id    dag_id      query_id  combination_index  \
# 0      model_0001  dag_0001  query_000001                  0
# 1      model_0001  dag_0001  query_000002                  0
# 2      model_0001  dag_0001  query_000003                  1
# 3      model_0001  dag_0001  query_000004                  1
# 4      model_0001  dag_0001  query_000005                  2
# ...           ...       ...           ...                ...
# 40315  model_1680  dag_0210  query_040316                  9
# 40316  model_1680  dag_0210  query_040317                 10
# 40317  model_1680  dag_0210  query_040318                 10
# 40318  model_1680  dag_0210  query_040319                 11
# 40319  model_1680  dag_0210  query_040320                 11
#
#        query_index_in_combination  num_query_nodes_param  \
# 0                               0                      1
# 1                               1                      1
# 2                               0                      1
# ...
